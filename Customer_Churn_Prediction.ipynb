# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')

# %%
df = pd.read_csv(r'C:\Users\USER\Downloads\Datasets\ML datasets\Telco_Customer_Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
df['Dependents'] = df['Dependents'].map({'Yes': 1, 'No': 0})
df['Partner'] = df['Partner'].map({'Yes': 1, 'No': 0})
df['PaperlessBilling'] = df['PaperlessBilling'].map({'Yes': 1, 'No': 0})
df['PhoneService'] = df['PhoneService'].map({'Yes': 1, 'No': 0})
df['gender'] = df['gender'].map({'Male': 1, 'Female': 0})

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0             0  No phone service             DSL             No          Yes
# 1             1                No             DSL            Yes           No
# 2             1                No             DSL            Yes          Yes
# 3             0  No phone service             DSL            Yes           No
# 4             1                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df = df.join(pd.get_dummies(df['MultipleLines'], prefix = 'ML'))
df = df.drop('MultipleLines', axis = 1)

# %%
df = df.join(pd.get_dummies(df['InternetService'], prefix = 'IS'))
df = df.drop('InternetService', axis = 1)

# %%
df = df.join(pd.get_dummies(df['OnlineSecurity'], prefix = 'OS'))
df = df.drop('OnlineSecurity', axis = 1)

# %%
df = df.join(pd.get_dummies(df['OnlineBackup'], prefix = 'OB'))
df = df.drop('OnlineBackup', axis = 1)

# %%
df = df.join(pd.get_dummies(df['DeviceProtection'], prefix = 'DP'))
df = df.drop('DeviceProtection', axis = 1)

# %%
df = df.join(pd.get_dummies(df['TechSupport'], prefix = 'TS'))
df = df.drop('TechSupport', axis = 1)

# %%
df = df.join(pd.get_dummies(df['StreamingTV'], prefix = 'STV'))
df = df.drop('StreamingTV', axis = 1)

# %%
df = df.join(pd.get_dummies(df['StreamingMovies'], prefix = 'SMV'))
df = df.drop('StreamingMovies', axis = 1)

# %%
df = df.join(pd.get_dummies(df['Contract']))
df = df.drop('Contract', axis = 1)

# %%
df = df.join(pd.get_dummies(df['PaymentMethod']))
df = df.drop('PaymentMethod', axis = 1)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  PaperlessBilling  MonthlyCharges TotalCharges Churn  ML_No  \
# 0             0                 1           29.85        29.85    No      0
# 1             1                 0           56.95       1889.5    No      1
# 2             1                 1           53.85       108.15   Yes      1
# 3             0                 0           42.30      1840.75    No      0
# 4             1                 1           70.70       151.65   Yes      1
#
#    ML_No phone service  ML_Yes  IS_DSL  IS_Fiber optic  IS_No  OS_No  \
# ...

# %%
df.shape
# Out:
# (7043, 42)

# %%
df['TotalCharges'].value_counts()
# Out:
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
df[df['TotalCharges'] == ' ']
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 488   4472-LVYGI       0              0        1           1       0
# 753   3115-CZMZD       1              0        0           1       0
# 936   5709-LVOEQ       0              0        1           1       0
# 1082  4367-NUYAO       1              0        1           1       0
# 1340  1371-DWPAZ       0              0        1           1       0
# 3331  7644-OMVMY       1              0        1           1       0
# 3826  3213-VVOLG       1              0        1           1       0
# 4380  2520-SGTTA       0              0        1           1       0
# 5218  2923-ARZLG       1              0        1           1       0
# 6670  4075-WKNIU       0              0        1           1       0
# 6754  2775-SEFEE       1              0        0           1       0
#
#       PhoneService  PaperlessBilling  MonthlyCharges TotalCharges Churn  \
# ...

# %%
df = df.drop(df.index[[488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754]], axis = 0)

# %%
df['TotalCharges'] = df['TotalCharges'].astype('float')

# %%
df.dtypes
# Out:
# customerID                    object
# gender                         int64
# SeniorCitizen                  int64
# Partner                        int64
# Dependents                     int64
# tenure                         int64
# PhoneService                   int64
# PaperlessBilling               int64
# MonthlyCharges               float64
# TotalCharges                 float64
# Churn                         object
# ML_No                          uint8
# ML_No phone service            uint8
# ML_Yes                         uint8
# IS_DSL                         uint8
# IS_Fiber optic                 uint8
# IS_No                          uint8
# OS_No                          uint8
# OS_No internet service         uint8
# OS_Yes                         uint8
# OB_No                          uint8
# OB_No internet service         uint8
# OB_Yes                         uint8
# DP_No                          uint8
# DP_No internet service         uint8
# ...

# %%
df['Churn'] = df['Churn'].map({'Yes': 1, 'No': 0})

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(df.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
df.drop('customerID', axis = 1, inplace = True)

# %%
target_corr = df.corr()['Churn'].apply(abs).sort_values()

# %%
target_corr
# Out:
# gender                       0.008545
# PhoneService                 0.011691
# ML_No phone service          0.011691
# ML_No                        0.032654
# ML_Yes                       0.040033
# SMV_Yes                      0.060860
# STV_Yes                      0.063254
# DP_Yes                       0.066193
# OB_Yes                       0.082307
# Mailed check                 0.090773
# Bank transfer (automatic)    0.118136
# IS_DSL                       0.124141
# STV_No                       0.128435
# SMV_No                       0.130920
# Credit card (automatic)      0.134687
# Partner                      0.149982
# SeniorCitizen                0.150541
# Dependents                   0.163128
# TS_Yes                       0.164716
# OS_Yes                       0.171270
# One year                     0.178225
# PaperlessBilling             0.191454
# MonthlyCharges               0.192858
# TotalCharges                 0.199484
# SMV_No internet service      0.227578
# ...

# %%
selected_corr = target_corr[-17:].index
selected_corr
# Out:
# Index(['SMV_No internet service', 'STV_No internet service',
#        'OB_No internet service', 'DP_No internet service',
#        'OS_No internet service', 'IS_No', 'TS_No internet service', 'DP_No',
#        'OB_No', 'Electronic check', 'Two year', 'IS_Fiber optic', 'TS_No',
#        'OS_No', 'tenure', 'Month-to-month', 'Churn'],
#       dtype='object')

# %%
selected_corr = list(selected_corr)

# %%
new_df = df[selected_corr]

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(new_df.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
new_df.head()
# Out:
#    SMV_No internet service  STV_No internet service  OB_No internet service  \
# 0                        0                        0                       0
# 1                        0                        0                       0
# 2                        0                        0                       0
# 3                        0                        0                       0
# 4                        0                        0                       0
#
#    DP_No internet service  OS_No internet service  IS_No  \
# 0                       0                       0      0
# 1                       0                       0      0
# 2                       0                       0      0
# 3                       0                       0      0
# 4                       0                       0      0
#
#    TS_No internet service  DP_No  OB_No  Electronic check  Two year  \
# 0                       0      1      0                 1         0
# ...

# %%
df['Churn'].value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X = new_df.drop('Churn', axis = 1)
y = new_df['Churn']

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy = 'minority', random_state = 5)
X_sm, y_sm = smote.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size = 0.20, random_state = 5, stratify = y_sm)

# %%
# RandomForest Classifier

forest = RandomForestClassifier()

forest.fit(X_train, y_train)

forest.score(X_train, y_train)
# Out:
# 0.8911622276029055

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
y_pred = forest.predict(X_test)

# %%
score = accuracy_score(y_test, y_pred)
print(score)
# Out:
# 0.8180058083252663

# %%
matrix = confusion_matrix(y_test, y_pred)
print(matrix)
print(classification_report(y_test, y_pred))
sns.heatmap(matrix, annot = True, cmap = 'YlGnBu')
# Out:
# [[770 263]
#  [113 920]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.80      1033
#            1       0.78      0.89      0.83      1033
#
#     accuracy                           0.82      2066
#    macro avg       0.82      0.82      0.82      2066
# weighted avg       0.82      0.82      0.82      2066
# <Axes: >
