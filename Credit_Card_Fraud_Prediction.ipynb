# %%
# Importing Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
cc = pd.read_csv(r'C:\Users\USER\Downloads\Datasets\ML datasets\creditcard_2023.csv')

# %%
cc.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.130006  0.727159  0.637735 -0.987020  0.293438 -0.941386  0.549020
# 1 -0.133118  0.347452  0.529808  0.140107  1.564246  0.574074  0.627719
# 2 -0.095576 -0.261297  0.690708 -0.272985  0.659201  0.805173  0.616874
# 3 -0.065130 -0.205698  0.575231 -0.752581  0.737483  0.592994  0.559535
# 4 -0.212660  1.049921  0.968046 -1.203171  1.029577  1.439310  0.241454
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
cc.shape
# Out:
# (568630, 31)

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
cc.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
cc.duplicated().sum()
# Out:
# 0

# %%
# Statistics of the data
cc.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486121  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %%
# checking the distribution of all numeric columns in the dataset
cc.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
# Checking the relationship between different columns in the data
plt.figure(figsize = (20, 10))
sns.heatmap(cc.corr(), annot = True, cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
# Distribuition of fraudulent transactions and legit transactions
cc['Class'].value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
# Checking the mean value of various columns based on the class. 
cc.groupby('Class').mean()
# Out:
#                   id        V1        V2        V3        V4        V5  \
# Class
# 0      142442.987714  0.505761 -0.491878  0.682095 -0.735981  0.338639
# 1      426186.012286 -0.505761  0.491878 -0.682095  0.735981 -0.338639
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0      0.435088  0.491234 -0.144294  0.585522  0.673665 -0.724278  0.768579
# 1     -0.435088 -0.491234  0.144294 -0.585522 -0.673665  0.724278 -0.768579
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.071105  0.805669  0.037948  0.573511  0.476377  0.410091 -0.244081
# 1     -0.071105 -0.805669 -0.037948 -0.573511 -0.476377 -0.410091  0.244081
#
#             V20      V21       V22       V23       V24       V25       V26  \
# Class
# 0     -0.179851 -0.10964 -0.014098 -0.010255  0.130107 -0.061847 -0.071052
# 1      0.179851  0.10964  0.014098  0.010255 -0.130107  0.061847  0.071052
#
# ...

# %%
# Importing machine learning dependies.
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
X = cc.drop('Class', axis = 1)
y = cc['Class']

# %%
# Splitting the data into training and testing data.
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ## AdaBoostClassifier

# %%
# Model training
model_ada = AdaBoostClassifier()
model_ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
# Model Evaluation on training data
X_train_predict = model_ada.predict(X_train)
training_score = accuracy_score(X_train_predict, y_train)
training_score
# Out:
# 0.9996746566308495

# %%
# Model Evaluation on test data
y_pred = model_ada.predict(X_test)
score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.9995867259905387

# %%
# Confusion Matrix on the predicted values
print(confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred), annot = True)
# Out:
# [[56845    18]
#  [   29 56834]]
# <Axes: >

# %%
# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56863
#            1       1.00      1.00      1.00     56863
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726
